# %%
import pandas as pd
pitch21 = pd.read_csv('data/pitches_21.csv')
pitch22 = pd.read_csv('data/pitches_22.csv')
pitch23 = pd.read_csv('data/pitches_23.csv')

# combined_df = pd.concat([season_21, season_22, season_23])

# %%
# combined_df.tail()
# Out:
#         Unnamed: 0                      gameid         GameDate  ab  pitchnum  \
# 717579      717580  2023/09/02/nyamlb-houmlb-1   9/2/2023 23:10  60         4
# 717580      717581  2023/09/02/nyamlb-houmlb-1   9/2/2023 23:10  57         3
# 717581      717582  2023/09/02/nyamlb-houmlb-1   9/2/2023 23:10  58         5
# 717582      717583  2023/09/02/nyamlb-houmlb-1   9/2/2023 23:10  58         6
# 717583      717584  2023/09/26/chnmlb-atlmlb-1  9/26/2023 23:20  42         4
#
#         inning  teambat  balls  strikes  outs  ...  horzbreak  \
# 717579     7.0        1    0.0      2.0   1.0  ...  15.084946
# 717580     7.0        0    0.0      2.0   1.0  ...   7.676146
# 717581     7.0        0    2.0      2.0   2.0  ...  16.145367
# 717582     7.0        0    2.0      2.0   2.0  ...   8.844625
# 717583     5.0        1    1.0      2.0   0.0  ...  13.806639
#
#        inducedvertbreak platelocside platelocheight hometeam_id  \
# 717579        12.236399    -0.442674       2.006670         117
# 717580        17.788908    -1.050967       2.320313         117
# 717581        12.247181    -0.841397       2.487577         117
# 717582         2.210124    -0.000184       1.811733         117
# 717583         0.455861    -1.591233       0.382095         144
#
#                   Home awayteam_id           Visitor venue_id  \
# 717579  Houston Astros         147  New York Yankees     2392
# 717580  Houston Astros         147  New York Yankees     2392
# 717581  Houston Astros         147  New York Yankees     2392
# 717582  Houston Astros         147  New York Yankees     2392
# 717583  Atlanta Braves         112      Chicago Cubs     4705
#
#               venue_name
# 717579  Minute Maid Park
# 717580  Minute Maid Park
# 717581  Minute Maid Park
# 717582  Minute Maid Park
# 717583       Truist Park
#
# [5 rows x 31 columns]

# %%
# Combine the dataframes
combined_data = pd.concat([pitch21, pitch22, pitch23], ignore_index=True)

# Filter for right-handed pitchers and specific pitch types
filtered_data = combined_data[(combined_data['pitcherthrows'] == 'R') &
                              (combined_data['pitchname'].isin(['FF', 'SL', 'CH', 'CU']))]

# Filter for strikes and balls count
filtered_data = filtered_data[(filtered_data['strikes'] == 2) & (filtered_data['balls'].isin([0, 1]))]

# Add binary column for strikeout outcomes
filtered_data['strikeout_binary'] = filtered_data['eventtype'].apply(lambda x: 1 if x in ['strikeout', 'strikeout_double_play'] else 0)

# Remove rows where pitchresult_desc is 'Ball - Pitchout' or 'Ball - Ball In Dirt'
filtered_data = filtered_data[~filtered_data['pitchresult_desc'].isin(['Ball - Pitchout', 'Ball - Ball In Dirt'])]

# Drop rows with missing values
filtered_data.dropna(inplace=True)

# Display number of remaining rows
print(f"Number of rows in filtered data: {len(filtered_data)}")
# Out:
# Number of rows in filtered data: 187405

# %%
filtered_data
# Out:
#          Unnamed: 0                      gameid         GameDate  ab  \
# 7                 8  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  32
# 10               11  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  33
# 29               30  2021/04/21/pitmlb-detmlb-2  4/21/2021 17:40  45
# 32               33  2021/04/25/arimlb-atlmlb-1  4/25/2021 12:20  12
# 37               38  2021/04/25/arimlb-atlmlb-1  4/25/2021 12:20  12
# ...             ...                         ...              ...  ..
# 2132575      717544  2023/08/30/clemlb-minmlb-1  8/30/2023 17:10  42
# 2132581      717550  2023/08/30/atlmlb-colmlb-1   8/31/2023 0:40  37
# 2132604      717573  2023/08/30/arimlb-lanmlb-1   8/31/2023 2:10  34
# 2132607      717576  2023/09/02/pitmlb-slnmlb-1   9/2/2023 23:15  54
# 2132612      717581  2023/09/02/nyamlb-houmlb-1   9/2/2023 23:10  57
#
#          pitchnum  inning  teambat  balls  strikes  outs  ...  \
# 7               4     4.0        1    1.0      2.0   1.0  ...
# 10              3     4.0        1    0.0      2.0   2.0  ...
# 29              4     6.0        1    1.0      2.0   0.0  ...
# 32              4     2.0        0    1.0      2.0   1.0  ...
# 37              3     2.0        0    0.0      2.0   1.0  ...
# ...           ...     ...      ...    ...      ...   ...  ...
# 2132575         5     6.0        1    1.0      2.0   0.0  ...
# 2132581         3     5.0        1    0.0      2.0   0.0  ...
# 2132604         5     4.0        1    1.0      2.0   0.0  ...
# 2132607         4     7.0        0    1.0      2.0   0.0  ...
# 2132612         3     7.0        0    0.0      2.0   1.0  ...
#
#         inducedvertbreak platelocside platelocheight hometeam_id  \
# 7               5.260902    -0.114617       2.546066         115
# 10              6.102530     0.880186       1.700091         115
# 29             -3.835304    -0.239593       2.348037         116
# 32              2.129060     1.028702       2.689594         144
# 37             13.794325     1.286732       2.807080         144
# ...                  ...          ...            ...         ...
# 2132575        -3.927244    -0.362439       1.593713         142
# 2132581         4.477882     0.436818       1.588252         115
# 2132604        14.275191     0.586442       1.884596         119
# 2132607        14.733393    -0.807034       4.470551         138
# 2132612        17.788908    -1.050967       2.320313         117
#
#                         Home awayteam_id               Visitor venue_id  \
# 7           Colorado Rockies         121         New York Mets       19
# 10          Colorado Rockies         121         New York Mets       19
# 29            Detroit Tigers         134    Pittsburgh Pirates     2394
# 32            Atlanta Braves         109  Arizona Diamondbacks     4705
# 37            Atlanta Braves         109  Arizona Diamondbacks     4705
# ...                      ...         ...                   ...      ...
# 2132575      Minnesota Twins         114   Cleveland Guardians     3312
# 2132581     Colorado Rockies         144        Atlanta Braves       19
# 2132604  Los Angeles Dodgers         109  Arizona Diamondbacks       22
# 2132607  St. Louis Cardinals         134    Pittsburgh Pirates     2889
# 2132612       Houston Astros         147      New York Yankees     2392
#
#                venue_name  strikeout_binary
# 7             Coors Field                 1
# 10            Coors Field                 0
# 29          Comerica Park                 0
# 32            Truist Park                 0
# 37            Truist Park                 0
# ...                   ...               ...
# 2132575      Target Field                 0
# 2132581       Coors Field                 0
# 2132604    Dodger Stadium                 0
# 2132607     Busch Stadium                 0
# 2132612  Minute Maid Park                 0
#
# [187405 rows x 32 columns]

# %%
filtered_data.to_csv('data/filtered_data.csv', index=False)

# %%
# # Drop rows with any NAs
# cleaned_df = combined_df.dropna()
# 
# # Converting GameDate to pandas Time Objects
# cleaned_df['GameDate'] = pd.to_datetime(cleaned_df['GameDate'])
# cleaned_df['Date'] = cleaned_df['GameDate'].dt.date
# cleaned_df['Time'] = cleaned_df['GameDate'].dt.time
# 
# cols = list(cleaned_df.columns)
# # find index of GameDate
# idx = cols.index('GameDate')
# # Basically put Date and Time right next to GameDate
# new_cols = cols[:idx + 1] + ['Date', 'Time'] + cols[idx + 1:-2]
# 
# cleaned_df = cleaned_df[new_cols].copy()
# 
# 
# # cleaned_df  = cleaned_df.sort_values(by = ['Date', 'Home', 'ab'])
# cleaned_df = cleaned_df.drop(columns = ['Unnamed: 0'])
# 
# 
# # cleaned_df = cleaned_df.sort_values(by=['gameid', 'ab', 'pitchnum'])
# 
# cleaned_df.to_pickle('data/aggregated_data.pkl')
# Out:
# /var/folders/3w/q_m3rh1s5xv5bh0kfpcqmd9r0000gn/T/ipykernel_54983/1404348024.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['GameDate'] = pd.to_datetime(cleaned_df['GameDate'])
# /var/folders/3w/q_m3rh1s5xv5bh0kfpcqmd9r0000gn/T/ipykernel_54983/1404348024.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Date'] = cleaned_df['GameDate'].dt.date
# /var/folders/3w/q_m3rh1s5xv5bh0kfpcqmd9r0000gn/T/ipykernel_54983/1404348024.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Time'] = cleaned_df['GameDate'].dt.time

# %%
# cleaned_df
# Out:
#                             gameid            GameDate        Date      Time  \
# 0       2021/04/17/nynmlb-colmlb-2 2021-04-16 20:33:00  2021-04-16  20:33:00
# 1       2021/04/17/nynmlb-colmlb-2 2021-04-16 20:33:00  2021-04-16  20:33:00
# 2       2021/04/17/nynmlb-colmlb-2 2021-04-16 20:33:00  2021-04-16  20:33:00
# 3       2021/04/17/nynmlb-colmlb-2 2021-04-16 20:33:00  2021-04-16  20:33:00
# 4       2021/04/17/nynmlb-colmlb-2 2021-04-16 20:33:00  2021-04-16  20:33:00
# ...                            ...                 ...         ...       ...
# 717579  2023/09/02/nyamlb-houmlb-1 2023-09-02 23:10:00  2023-09-02  23:10:00
# 717580  2023/09/02/nyamlb-houmlb-1 2023-09-02 23:10:00  2023-09-02  23:10:00
# 717581  2023/09/02/nyamlb-houmlb-1 2023-09-02 23:10:00  2023-09-02  23:10:00
# 717582  2023/09/02/nyamlb-houmlb-1 2023-09-02 23:10:00  2023-09-02  23:10:00
# 717583  2023/09/26/chnmlb-atlmlb-1 2023-09-26 23:20:00  2023-09-26  23:20:00
#
#         ab  pitchnum  inning  teambat  balls  strikes  ...  horzbreak  \
# 0       31         1     4.0        1    0.0      0.0  ...  14.701180
# 1       31         2     4.0        1    0.0      1.0  ...  -2.161110
# 2       31         3     4.0        1    1.0      1.0  ...  13.426973
# 3       32         1     4.0        1    0.0      0.0  ...  14.428921
# 4       35         1     5.0        0    0.0      0.0  ...   3.791252
# ...     ..       ...     ...      ...    ...      ...  ...        ...
# 717579  60         4     7.0        1    0.0      2.0  ...  15.084946
# 717580  57         3     7.0        0    0.0      2.0  ...   7.676146
# 717581  58         5     7.0        0    2.0      2.0  ...  16.145367
# 717582  58         6     7.0        0    2.0      2.0  ...   8.844625
# 717583  42         4     5.0        1    1.0      2.0  ...  13.806639
#
#        inducedvertbreak platelocside platelocheight hometeam_id  \
# 0              7.648054     0.143656       1.514166         115
# 1              4.845070     1.277162       1.246100         115
# 2             11.059589    -0.826248       2.734800         115
# 3              7.975150     0.330990       1.054213         115
# 4             10.746025     0.064407       3.774802         115
# ...                 ...          ...            ...         ...
# 717579        12.236399    -0.442674       2.006670         117
# 717580        17.788908    -1.050967       2.320313         117
# 717581        12.247181    -0.841397       2.487577         117
# 717582         2.210124    -0.000184       1.811733         117
# 717583         0.455861    -1.591233       0.382095         144
#
#                     Home awayteam_id           Visitor venue_id  \
# 0       Colorado Rockies         121     New York Mets       19
# 1       Colorado Rockies         121     New York Mets       19
# 2       Colorado Rockies         121     New York Mets       19
# 3       Colorado Rockies         121     New York Mets       19
# 4       Colorado Rockies         121     New York Mets       19
# ...                  ...         ...               ...      ...
# 717579    Houston Astros         147  New York Yankees     2392
# 717580    Houston Astros         147  New York Yankees     2392
# 717581    Houston Astros         147  New York Yankees     2392
# 717582    Houston Astros         147  New York Yankees     2392
# 717583    Atlanta Braves         112      Chicago Cubs     4705
#
#               venue_name
# 0            Coors Field
# 1            Coors Field
# 2            Coors Field
# 3            Coors Field
# 4            Coors Field
# ...                  ...
# 717579  Minute Maid Park
# 717580  Minute Maid Park
# 717581  Minute Maid Park
# 717582  Minute Maid Park
# 717583       Truist Park
#
# [2127939 rows x 32 columns]

# %%
# cleaned_df.to_pickle('data/aggregated_data.pkl')
