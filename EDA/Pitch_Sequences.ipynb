# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


season_21 = pd.read_csv('../data/pitches_21.csv')
season_22 = pd.read_csv('../data/pitches_21.csv')
season_23 = pd.read_csv('../data/pitches_21.csv')

# %%
combined_df = pd.concat([season_21, season_22, season_23])

# Drop rows with any NAs
cleaned_df = combined_df.dropna()

# %%
season_21.columns
# Out:
# Index(['Unnamed: 0', 'gameid', 'GameDate', 'ab', 'pitchnum', 'inning',
#        'teambat', 'balls', 'strikes', 'outs', 'pitcher', 'pitcherthrows',
#        'batter', 'batterside', 'pitchresult', 'pitchresult_desc', 'eventtype',
#        'pitchname', 'pitchname_desc', 'spinrate', 'relspeed', 'horzbreak',
#        'inducedvertbreak', 'platelocside', 'platelocheight', 'hometeam_id',
#        'Home', 'awayteam_id', 'Visitor', 'venue_id', 'venue_name'],
#       dtype='object')

# %%
season_22.dtypes
# Out:
# Unnamed: 0            int64
# gameid               object
# GameDate             object
# ab                    int64
# pitchnum              int64
# inning              float64
# teambat               int64
# balls               float64
# strikes             float64
# outs                float64
# pitcher              object
# pitcherthrows        object
# batter               object
# batterside           object
# pitchresult          object
# pitchresult_desc     object
# eventtype            object
# pitchname            object
# pitchname_desc       object
# spinrate            float64
# relspeed            float64
# horzbreak           float64
# inducedvertbreak    float64
# platelocside        float64
# platelocheight      float64
# hometeam_id           int64
# Home                 object
# awayteam_id           int64
# Visitor              object
# venue_id              int64
# venue_name           object
# dtype: object

# %% [markdown]
# ## Adding a Date and Time Column with datetime pandas objects

# %%
season_21['GameDate'] = pd.to_datetime(season_21['GameDate'])
season_21['Date'] = season_21['GameDate'].dt.date
season_21['Time'] = season_21['GameDate'].dt.time

cols = list(season_21.columns)
# find index of GameDate
idx = cols.index('GameDate')
# Basically put Date and Time right next to GameDate 
new_cols = cols[:idx + 1] + ['Date', 'Time'] + cols[idx + 1:-2]

season_21 = season_21[new_cols].copy()
season_21
# Out:
#         Unnamed: 0                      gameid            GameDate  \
# 0                1  2021/04/17/nynmlb-colmlb-2 2021-04-16 20:33:00
# 1                2  2021/04/17/nynmlb-colmlb-2 2021-04-16 20:33:00
# 2                3  2021/04/17/nynmlb-colmlb-2 2021-04-16 20:33:00
# 3                4  2021/04/17/nynmlb-colmlb-2 2021-04-16 20:33:00
# 4                5  2021/04/17/nynmlb-colmlb-2 2021-04-16 20:33:00
# ...            ...                         ...                 ...
# 706904      706905  2021/10/02/nynmlb-atlmlb-1 2021-10-02 23:15:00
# 706905      706906  2021/10/02/nynmlb-atlmlb-1 2021-10-02 23:15:00
# 706906      706907  2021/10/02/nynmlb-atlmlb-1 2021-10-02 23:15:00
# 706907      706908  2021/10/02/nynmlb-atlmlb-1 2021-10-02 23:15:00
# 706908      706909  2021/10/02/nynmlb-atlmlb-1 2021-10-02 23:15:00
#
#               Date      Time  ab  pitchnum  inning  teambat  balls  ...  \
# 0       2021-04-16  20:33:00  31         1     4.0        1    0.0  ...
# 1       2021-04-16  20:33:00  31         2     4.0        1    0.0  ...
# 2       2021-04-16  20:33:00  31         3     4.0        1    1.0  ...
# 3       2021-04-16  20:33:00  32         1     4.0        1    0.0  ...
# 4       2021-04-16  20:33:00  35         1     5.0        0    0.0  ...
# ...            ...       ...  ..       ...     ...      ...    ...  ...
# 706904  2021-10-02  23:15:00  42         8     5.0        1    0.0  ...
# 706905  2021-10-02  23:15:00  43         1     5.0        1    0.0  ...
# 706906  2021-10-02  23:15:00  43         2     5.0        1    0.0  ...
# 706907  2021-10-02  23:15:00  43         3     5.0        1    1.0  ...
# 706908  2021-10-02  23:15:00  43         4     5.0        1    1.0  ...
#
#         horzbreak  inducedvertbreak platelocside platelocheight hometeam_id  \
# 0       14.701180          7.648054     0.143656       1.514166         115
# 1       -2.161110          4.845070     1.277162       1.246100         115
# 2       13.426973         11.059589    -0.826248       2.734800         115
# 3       14.428921          7.975150     0.330990       1.054213         115
# 4        3.791252         10.746025     0.064407       3.774802         115
# ...           ...               ...          ...            ...         ...
# 706904  12.777756          5.362740    -0.295482       2.166446         144
# 706905   7.615064         -0.164651    -0.438475       1.132619         144
# 706906   5.507193         14.064531     0.894155       2.744111         144
# 706907   5.922451         13.146690     0.216244       3.111117         144
# 706908   5.134937         12.946681    -0.208658       3.611532         144
#
#                     Home awayteam_id        Visitor venue_id   venue_name
# 0       Colorado Rockies         121  New York Mets       19  Coors Field
# 1       Colorado Rockies         121  New York Mets       19  Coors Field
# 2       Colorado Rockies         121  New York Mets       19  Coors Field
# 3       Colorado Rockies         121  New York Mets       19  Coors Field
# 4       Colorado Rockies         121  New York Mets       19  Coors Field
# ...                  ...         ...            ...      ...          ...
# 706904    Atlanta Braves         121  New York Mets     4705  Truist Park
# 706905    Atlanta Braves         121  New York Mets     4705  Truist Park
# 706906    Atlanta Braves         121  New York Mets     4705  Truist Park
# 706907    Atlanta Braves         121  New York Mets     4705  Truist Park
# 706908    Atlanta Braves         121  New York Mets     4705  Truist Park
#
# [706909 rows x 33 columns]

# %% [markdown]
# ## Sorting the DataFrame chronologically - then by Team Name, and then by "at bats"

# %%
season_21  = season_21.sort_values(by = ['Date', 'Home', 'ab'])
season_21 = season_21.drop(columns = ['Unnamed: 0'])
season_21
#season_21.to_csv('data/pitches.csv')
# Out:
#                             gameid            GameDate        Date      Time  \
# 104858  2021/04/01/pitmlb-chnmlb-1 2021-04-01 13:20:00  2021-04-01  13:20:00
# 104859  2021/04/01/pitmlb-chnmlb-1 2021-04-01 13:20:00  2021-04-01  13:20:00
# 104860  2021/04/01/pitmlb-chnmlb-1 2021-04-01 13:20:00  2021-04-01  13:20:00
# 104861  2021/04/01/pitmlb-chnmlb-1 2021-04-01 13:20:00  2021-04-01  13:20:00
# 104862  2021/04/01/pitmlb-chnmlb-1 2021-04-01 13:20:00  2021-04-01  13:20:00
# ...                            ...                 ...         ...       ...
# 563007  2021/10/03/bosmlb-wasmlb-1 2021-10-03 19:05:00  2021-10-03  19:05:00
# 563008  2021/10/03/bosmlb-wasmlb-1 2021-10-03 19:05:00  2021-10-03  19:05:00
# 563009  2021/10/03/bosmlb-wasmlb-1 2021-10-03 19:05:00  2021-10-03  19:05:00
# 565478  2021/10/03/bosmlb-wasmlb-1 2021-10-03 19:05:00  2021-10-03  19:05:00
# 565479  2021/10/03/bosmlb-wasmlb-1 2021-10-03 19:05:00  2021-10-03  19:05:00
#
#         ab  pitchnum  inning  teambat  balls  strikes  ...  horzbreak  \
# 104858   1         1     1.0        0    0.0      0.0  ...   7.899302
# 104859   1         2     1.0        0    1.0      0.0  ...   3.684525
# 104860   1         3     1.0        0    1.0      1.0  ...   7.670026
# 104861   1         4     1.0        0    2.0      1.0  ...   7.343168
# 104862   1         5     1.0        0    3.0      1.0  ...   5.351965
# ...     ..       ...     ...      ...    ...      ...  ...        ...
# 563007  81         4     9.0        1    1.0      2.0  ...   2.049364
# 563008  81         5     9.0        1    1.0      2.0  ...  -4.902229
# 563009  82         1     9.0        1    0.0      0.0  ...   0.660327
# 565478  82         2     9.0        1    0.0      1.0  ...   0.548382
# 565479  82         3     9.0        1    0.0      2.0  ...  -1.853484
#
#        inducedvertbreak platelocside platelocheight hometeam_id  \
# 104858        20.196724    -0.925614       3.118610         112
# 104859        20.294086    -0.000916       1.945728         112
# 104860        18.184725    -1.969467       3.548406         112
# 104861        19.395239    -1.160865       2.435223         112
# 104862        17.362413     0.046086       2.654030         112
# ...                 ...          ...            ...         ...
# 563007        18.104872     0.719018       2.699417         120
# 563008       -20.987835     0.399907       1.736541         120
# 563009        19.385929     0.487332       2.043276         120
# 565478        20.448322     0.333695       3.081872         120
# 565479       -22.287155     0.207946       3.121632         120
#
#                         Home awayteam_id             Visitor venue_id  \
# 104858          Chicago Cubs         134  Pittsburgh Pirates       17
# 104859          Chicago Cubs         134  Pittsburgh Pirates       17
# 104860          Chicago Cubs         134  Pittsburgh Pirates       17
# 104861          Chicago Cubs         134  Pittsburgh Pirates       17
# 104862          Chicago Cubs         134  Pittsburgh Pirates       17
# ...                      ...         ...                 ...      ...
# 563007  Washington Nationals         111      Boston Red Sox     3309
# 563008  Washington Nationals         111      Boston Red Sox     3309
# 563009  Washington Nationals         111      Boston Red Sox     3309
# 565478  Washington Nationals         111      Boston Red Sox     3309
# 565479  Washington Nationals         111      Boston Red Sox     3309
#
#             venue_name
# 104858   Wrigley Field
# 104859   Wrigley Field
# 104860   Wrigley Field
# 104861   Wrigley Field
# 104862   Wrigley Field
# ...                ...
# 563007  Nationals Park
# 563008  Nationals Park
# 563009  Nationals Park
# 565478  Nationals Park
# 565479  Nationals Park
#
# [706909 rows x 32 columns]

# %%
season_21 = season_21.sort_values(by=['gameid', 'ab', 'pitchnum'])

# Step 2: Identify strikeout events
strikeout_df = season_21[season_21['eventtype'] == 'strikeout']

# Step 3: For each strikeout, find the previous pitch (the one immediately before the strikeout)
# Create a new column that shifts the pitchname by 1 to represent the previous pitch
season_21['prev_pitchname'] = season_21['pitchname'].shift(1)

# Also shift other columns to ensure the previous pitch belongs to the same at-bat and game
season_21['prev_gameid'] = season_21['gameid'].shift(1)
season_21['prev_ab'] = season_21['ab'].shift(1)

# Step 4: Filter for pitches that are strikeouts and where the previous pitch is from the same game and at-bat
strikeout_with_prev_pitch = season_21[
    (season_21['eventtype'] == 'strikeout') &
    (season_21['gameid'] == season_21['prev_gameid']) &
    (season_21['ab'] == season_21['prev_ab'])
]

# Step 5: Group by the previous pitch and the strikeout pitch
pitch_pairs = strikeout_with_prev_pitch.groupby(
    ['prev_pitchname', 'pitchname']
).size().reset_index(name='count')

# Step 6: Sort the results by count to find the most common pitch pairs (previous and strikeout pitch)
most_common_pitch_pairs = pitch_pairs.sort_values(by='count', ascending=False)

# Step 7: Display the most common pitch pairs leading to strikeouts
print(most_common_pitch_pairs)
print(most_common_pitch_pairs.nunique())
# Out:
#    prev_pitchname pitchname  count
# 37             FF        FF   6483
# 83             SL        SL   4612
# 42             FF        SL   3424
# 78             SL        FF   2604
# 0              CH        CH   1614
# ..            ...       ...    ...
# 54             FT        FT      1
# 80             SL        FT      1
# 11             CS        KC      1
# 57             KC        CU      1
# 74             SL        CS      1
#
# [84 rows x 3 columns]
# prev_pitchname    12
# pitchname         12
# count             62
# dtype: int64

# %%
top_n = 10
top_pitch_pairs = most_common_pitch_pairs.head(top_n)

# Step 2: Create a bar chart
plt.figure(figsize=(10, 6))

# X-axis labels will be the combination of the previous pitch and strikeout pitch
pitch_combinations = top_pitch_pairs.apply(lambda row: f"{row['prev_pitchname']} -> {row['pitchname']}", axis=1)

# Plot the bar chart
plt.bar(pitch_combinations, top_pitch_pairs['count'], color='blue')

# Step 3: Label the chart
plt.title(f"Top {top_n} Most Common Pitch Combinations Leading to Strikeouts")
plt.xlabel('Pitch Combination (Previous -> Strikeout)')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')

# Display the chart
plt.tight_layout()
plt.show()

# %%
season_22.head(20)
# Out:
#     Unnamed: 0                      gameid         GameDate  ab  pitchnum  \
# 0            1  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  31         1
# 1            2  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  31         2
# 2            3  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  31         3
# 3            4  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  32         1
# 4            5  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  35         1
# 5            6  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  32         2
# 6            7  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  32         3
# 7            8  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  32         4
# 8            9  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  33         1
# 9           10  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  33         2
# 10          11  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  33         3
# 11          12  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  34         1
# 12          13  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  34         2
# 13          14  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  34         3
# 14          15  2021/04/25/arimlb-atlmlb-1  4/25/2021 12:20  47         5
# 15          16  2021/04/25/arimlb-atlmlb-1  4/25/2021 12:20  48         1
# 16          17  2021/04/25/arimlb-atlmlb-1  4/25/2021 12:20  48         2
# 17          18  2021/04/25/arimlb-atlmlb-1  4/25/2021 12:20  12         6
# 18          19  2021/04/18/chamlb-bosmlb-1  4/18/2021 13:10  31         4
# 19          20  2021/04/18/chamlb-bosmlb-1  4/18/2021 13:10  31         5
#
#     inning  teambat  balls  strikes  outs  ...  horzbreak inducedvertbreak  \
# 0      4.0        1    0.0      0.0   1.0  ...  14.701180         7.648054
# 1      4.0        1    0.0      1.0   1.0  ...  -2.161110         4.845070
# 2      4.0        1    1.0      1.0   1.0  ...  13.426973        11.059589
# 3      4.0        1    0.0      0.0   1.0  ...  14.428921         7.975150
# 4      5.0        0    0.0      0.0   1.0  ...   3.791252        10.746025
# 5      4.0        1    1.0      0.0   1.0  ...  15.674111         7.154369
# 6      4.0        1    1.0      1.0   1.0  ...  14.973265         8.511888
# 7      4.0        1    1.0      2.0   1.0  ...  -1.077158         5.260902
# 8      4.0        1    0.0      0.0   2.0  ...  12.063048         9.522058
# 9      4.0        1    0.0      1.0   2.0  ...   4.873104         6.592208
# 10     4.0        1    0.0      2.0   2.0  ...  -0.019169         6.102530
# 11     5.0        0    0.0      0.0   0.0  ...   3.704415        11.381925
# 12     5.0        0    0.0      1.0   0.0  ...  -0.498579         0.148768
# 13     5.0        0    1.0      1.0   0.0  ...  -5.885554        -0.504743
# 14     6.0        1    3.0      1.0   1.0  ...   3.417144        18.279982
# 15     6.0        1    0.0      0.0   1.0  ...   1.050626        13.141785
# 16     6.0        1    0.0      1.0   1.0  ...  -5.807469         7.003082
# 17     2.0        0    2.0      2.0   1.0  ...   5.329813        15.719269
# 18     4.0        1    3.0      0.0   2.0  ... -11.587748         5.455310
# 19     4.0        1    3.0      1.0   2.0  ... -10.295907         3.858305
#
#    platelocside platelocheight hometeam_id              Home awayteam_id  \
# 0      0.143656       1.514166         115  Colorado Rockies         121
# 1      1.277162       1.246100         115  Colorado Rockies         121
# 2     -0.826248       2.734800         115  Colorado Rockies         121
# 3      0.330990       1.054213         115  Colorado Rockies         121
# 4      0.064407       3.774802         115  Colorado Rockies         121
# 5     -0.638243       1.884003         115  Colorado Rockies         121
# 6     -1.296625       2.196844         115  Colorado Rockies         121
# 7     -0.114617       2.546066         115  Colorado Rockies         121
# 8     -0.639474       2.198678         115  Colorado Rockies         121
# 9      0.492799       2.455150         115  Colorado Rockies         121
# 10     0.880186       1.700091         115  Colorado Rockies         121
# 11     0.084060       3.053724         115  Colorado Rockies         121
# 12    -1.074230       2.838166         115  Colorado Rockies         121
# 13    -0.167112       2.691323         115  Colorado Rockies         121
# 14     0.663778       1.232030         144    Atlanta Braves         109
# 15     0.992153       1.593526         144    Atlanta Braves         109
# 16     1.026742       3.582807         144    Atlanta Braves         109
# 17     0.497709       0.654149         144    Atlanta Braves         109
# 18     0.823788       2.921698         111    Boston Red Sox         145
# 19     0.270016       1.477237         111    Boston Red Sox         145
#
#                  Visitor venue_id   venue_name
# 0          New York Mets       19  Coors Field
# 1          New York Mets       19  Coors Field
# 2          New York Mets       19  Coors Field
# 3          New York Mets       19  Coors Field
# 4          New York Mets       19  Coors Field
# 5          New York Mets       19  Coors Field
# 6          New York Mets       19  Coors Field
# 7          New York Mets       19  Coors Field
# 8          New York Mets       19  Coors Field
# 9          New York Mets       19  Coors Field
# 10         New York Mets       19  Coors Field
# 11         New York Mets       19  Coors Field
# 12         New York Mets       19  Coors Field
# 13         New York Mets       19  Coors Field
# 14  Arizona Diamondbacks     4705  Truist Park
# 15  Arizona Diamondbacks     4705  Truist Park
# 16  Arizona Diamondbacks     4705  Truist Park
# 17  Arizona Diamondbacks     4705  Truist Park
# 18     Chicago White Sox        3  Fenway Park
# 19     Chicago White Sox        3  Fenway Park
#
# [20 rows x 31 columns]

# %%
season_23.head()
# Out:
#    Unnamed: 0                      gameid         GameDate  ab  pitchnum  \
# 0           1  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  31         1
# 1           2  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  31         2
# 2           3  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  31         3
# 3           4  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  32         1
# 4           5  2021/04/17/nynmlb-colmlb-2  4/16/2021 20:33  35         1
#
#    inning  teambat  balls  strikes  outs  ...  horzbreak inducedvertbreak  \
# 0     4.0        1    0.0      0.0   1.0  ...  14.701180         7.648054
# 1     4.0        1    0.0      1.0   1.0  ...  -2.161110         4.845070
# 2     4.0        1    1.0      1.0   1.0  ...  13.426973        11.059589
# 3     4.0        1    0.0      0.0   1.0  ...  14.428921         7.975150
# 4     5.0        0    0.0      0.0   1.0  ...   3.791252        10.746025
#
#   platelocside platelocheight hometeam_id              Home awayteam_id  \
# 0     0.143656       1.514166         115  Colorado Rockies         121
# 1     1.277162       1.246100         115  Colorado Rockies         121
# 2    -0.826248       2.734800         115  Colorado Rockies         121
# 3     0.330990       1.054213         115  Colorado Rockies         121
# 4     0.064407       3.774802         115  Colorado Rockies         121
#
#          Visitor venue_id   venue_name
# 0  New York Mets       19  Coors Field
# 1  New York Mets       19  Coors Field
# 2  New York Mets       19  Coors Field
# 3  New York Mets       19  Coors Field
# 4  New York Mets       19  Coors Field
#
# [5 rows x 31 columns]

# %% [markdown]
# ## All the dataframes are the same shape!

# %%
print(f"shape for 21: \n {season_21.shape}")
print(f"shape for 22: \n {season_22.shape}")
print(f"shape for 23: \n {season_23.shape}")
# Out:
# shape for 21:
#  (706909, 35)
# shape for 22:
#  (706909, 31)
# shape for 23:
#  (706909, 31)

# %%
print(f"unique for 21: \n {season_21.nunique()}")
# Out:
# unique for 21:
#  gameid                2423
# GameDate              1561
# Date                   183
# Time                   107
# ab                     123
# pitchnum                16
# inning                  16
# teambat                  2
# balls                    4
# strikes                  4
# outs                     3
# pitcher                907
# pitcherthrows            2
# batter                1047
# batterside               2
# pitchresult             16
# pitchresult_desc        16
# eventtype               46
# pitchname               14
# pitchname_desc          14
# spinrate            653447
# relspeed            619685
# horzbreak           700866
# inducedvertbreak    696006
# platelocside        703379
# platelocheight      692680
# hometeam_id             30
# Home                    30
# awayteam_id             30
# Visitor                 30
# venue_id                32
# venue_name              33
# prev_pitchname          14
# prev_gameid           2423
# prev_ab                123
# dtype: int64

# %%
print(f"unique for 22: \n {season_22.nunique()}")
# Out:
# unique for 22:
#  Unnamed: 0          706909
# gameid                2423
# GameDate              1561
# ab                     123
# pitchnum                16
# inning                  16
# teambat                  2
# balls                    4
# strikes                  4
# outs                     3
# pitcher                907
# pitcherthrows            2
# batter                1047
# batterside               2
# pitchresult             16
# pitchresult_desc        16
# eventtype               46
# pitchname               14
# pitchname_desc          14
# spinrate            653447
# relspeed            619685
# horzbreak           700866
# inducedvertbreak    696006
# platelocside        703379
# platelocheight      692680
# hometeam_id             30
# Home                    30
# awayteam_id             30
# Visitor                 30
# venue_id                32
# venue_name              33
# dtype: int64

# %%
print(f"unique for 23: \n {season_23.nunique()}")
# it seems like there are 2423 unique entries in each df
# Out:
# unique for 23:
#  Unnamed: 0          706909
# gameid                2423
# GameDate              1561
# ab                     123
# pitchnum                16
# inning                  16
# teambat                  2
# balls                    4
# strikes                  4
# outs                     3
# pitcher                907
# pitcherthrows            2
# batter                1047
# batterside               2
# pitchresult             16
# pitchresult_desc        16
# eventtype               46
# pitchname               14
# pitchname_desc          14
# spinrate            653447
# relspeed            619685
# horzbreak           700866
# inducedvertbreak    696006
# platelocside        703379
# platelocheight      692680
# hometeam_id             30
# Home                    30
# awayteam_id             30
# Visitor                 30
# venue_id                32
# venue_name              33
# dtype: int64

# %% [markdown]
# ## Looking for duplicates

# %%
duplicates = season_21.duplicated()
print(duplicates.sum())
duplicates = season_22.duplicated()
print(duplicates.sum())
duplicates = season_23.duplicated()
print(duplicates.sum())
# no duplicates lets go
# Out:
# 0
# 0
# 0

# %% [markdown]
# ## Creating a barplot displaying the frequency of each pitch type for each pitch result

# %%
grouped_data = season_21.groupby(['pitchresult', 'pitchname']).size().reset_index(name='count')

# %%
plt.figure(figsize=(12, 8))

# Making a barplot 
sns.barplot(x='pitchresult', y='count', hue='pitchname', data=grouped_data)

# Adding titles and labels
plt.title('Distribution of Pitch Types by Pitch Result')
plt.xlabel('Pitch Result')
plt.ylabel('Count')

plt.legend(title='Pitch Name')
plt.show()

# %% [markdown]
# ## Showing what the Pitch Name and Pitch Result shorthands mean

# %%
# I have no idea what half the stuff means  
unique_pitch_results = season_21[['pitchresult', 'pitchresult_desc']].drop_duplicates()

unique_pitch_results
# Out:
#        pitchresult           pitchresult_desc
# 97305            C            Strike - Called
# 97304            X     Hit Into Play - Out(s)
# 97303            F              Strike - Foul
# 97302            B              Ball - Called
# 97298            D  Hit Into Play - No Out(s)
# 97297            T          Strike - Foul Tip
# 97288            E     Hit Into Play - Run(s)
# 97287            S          Strike - Swinging
# 97258           *B        Ball - Ball In Dirt
# 96889            W  Strike - Swinging Blocked
# 96893            H        Ball - Hit by Pitch
# 97040            L         Strike - Foul Bunt
# 98736            M       Strike - Missed Bunt
# 104795           P            Ball - Pitchout
# 84203            O     Strike - Bunt Foul Tip
# 127551           C                        NaN
# 127559           B                        NaN
# 127628           F                        NaN
# 127607           S                        NaN
# 127687           X                        NaN
# 127694           D                        NaN
# 127788           W                        NaN
# 147235           E                        NaN
# 114844          *B                        NaN
# 114152           L                        NaN
# 389344           R  Strike - Foul on Pitchout
# 203070         NaN                        NaN

# %%
# I have no idea what half the stuff means (but for pitchnames) 
unique_pitch_results = season_21[['pitchname', 'pitchname_desc']].drop_duplicates()

print(unique_pitch_results.size)

unique_pitch_results
# Out:
# 46
#        pitchname pitchname_desc
# 97305         FC         Cutter
# 97304         SL         Slider
# 97303         FF   Four-seam FB
# 97302         KC  Knuckle Curve
# 97300         FS       Splitter
# 97276         CH       Changeup
# 97271         CS     Slow Curve
# 97270         SI         Sinker
# 97250         CU      Curveball
# 72849         SC      Screwball
# 60337         FA       Fastball
# 49657         FT    Two-seam FB
# 46870         EP   Eephus Pitch
# 40371         KN    Knuckleball
# 127551        FF            NaN
# 127559        SL            NaN
# 127651        KC            NaN
# 127607        CH            NaN
# 127524        CU            NaN
# 127760        SI            NaN
# 147292        FS            NaN
# 130112        FC            NaN
# 203070       NaN            NaN

# %%
unique_event_type = season_21['eventtype'].unique()
unique_event_type
# 
# nan_count = season_21['pitchresult'].isna().sum()
# print(nan_count)
# Out:
# array(['called_strike', 'field_out', 'foul', 'ball', 'single', 'foul_tip',
#        'strikeout', 'swinging_strike', 'double', 'blocked_ball', 'walk',
#        'swinging_strike_blocked', 'hit_by_pitch', 'home_run',
#        'field_error', 'grounded_into_double_play', 'force_out',
#        'foul_bunt', 'triple', 'sac_fly', 'missed_bunt', 'fielders_choice',
#        'sac_bunt', 'stolen_base_2b', 'double_play', 'stolen_base_3b',
#        'wild_pitch', 'caught_stealing_2b', 'passed_ball',
#        'fielders_choice_out', 'defensive_indiff', 'catcher_interf',
#        'caught_stealing_3b', 'strikeout_double_play',
#        'sac_fly_double_play', 'pitchout', 'balk', 'bunt_foul_tip',
#        'triple_play', 'sac_bunt_double_play',
#        'pickoff_caught_stealing_2b', 'intent_walk',
#        'caught_stealing_home', 'foul_pitchout', nan, 'other_advance',
#        'stolen_base_home'], dtype=object)

# %%
cluster_df = season_22.groupby(['pitchname']).size().reset_index(name='count')
cluster_df
# Out:
#    pitchname   count
# 0         CH   80621
# 1         CS     175
# 2         CU   59540
# 3         EP      43
# 4         FA     425
# 5         FC   46567
# 6         FF  248968
# 7         FS   10364
# 8         FT      90
# 9         KC   13544
# 10        KN      58
# 11        SC       1
# 12        SI  110444
# 13        SL  136068

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
features = ['relspeed', 'spinrate', 'horzbreak']
# I think that these three have different distributions & they are not all pos
scaler = StandardScaler()

season_21[features] = scaler.fit_transform(season_21[features])
X = season_21[features].dropna()

# %%
NA_rows = season_21[season_21.isna().any(axis=1)]
# we're looking at all the rows with NaN values - at first glance it seems as if there are ~1000 rows with no spinrate information 
NA_rows
# Out:
#                             gameid            GameDate        Date      Time  \
# 97305   2021/04/01/arimlb-sdnmlb-1 2021-04-01 13:10:00  2021-04-01  13:10:00
# 98726   2021/04/01/atlmlb-phimlb-1 2021-04-01 15:05:00  2021-04-01  15:05:00
# 110770  2021/04/01/clemlb-detmlb-1 2021-04-01 12:10:00  2021-04-01  12:10:00
# 38695   2021/04/09/anamlb-tormlb-1 2021-04-09 18:07:00  2021-04-09  18:07:00
# 37245   2021/04/12/sdnmlb-pitmlb-1 2021-04-12 18:35:00  2021-04-12  18:35:00
# ...                            ...                 ...         ...       ...
# 699171  2021/10/02/sdnmlb-sfnmlb-1 2021-10-02 20:05:00  2021-10-02  20:05:00
# 698962  2021/10/02/sdnmlb-sfnmlb-1 2021-10-02 20:05:00  2021-10-02  20:05:00
# 597538  2021/10/03/sdnmlb-sfnmlb-1 2021-10-03 19:05:00  2021-10-03  19:05:00
# 538681  2021/10/03/sdnmlb-sfnmlb-1 2021-10-03 19:05:00  2021-10-03  19:05:00
# 632998  2021/10/03/sdnmlb-sfnmlb-1 2021-10-03 19:05:00  2021-10-03  19:05:00
#
#         ab  pitchnum  inning  teambat  balls  strikes  ...  platelocheight  \
# 97305    1         1     1.0        0    0.0      0.0  ...        2.616580
# 98726   28         1     4.0        0    0.0      0.0  ...        1.845386
# 110770   8         1     1.0        1    0.0      0.0  ...        4.340580
# 38695    2         1     1.0        0    0.0      0.0  ...        1.679699
# 37245   13         1     2.0        1    0.0      0.0  ...        2.539548
# ...     ..       ...     ...      ...    ...      ...  ...             ...
# 699171  46         3     7.0        0    1.0      1.0  ...        2.828668
# 698962  51         4     7.0        1    1.0      2.0  ...        3.114645
# 597538  49         4     6.0        0    1.0      2.0  ...        2.327676
# 538681  68         3     8.0        0    0.0      2.0  ...        2.034462
# 632998  69         5     8.0        0    3.0      1.0  ...        1.520911
#
#        hometeam_id                   Home awayteam_id               Visitor  \
# 97305          135       San Diego Padres         109  Arizona Diamondbacks
# 98726          143  Philadelphia Phillies         144        Atlanta Braves
# 110770         116         Detroit Tigers         114     Cleveland Indians
# 38695          141      Toronto Blue Jays         108    Los Angeles Angels
# 37245          134     Pittsburgh Pirates         135      San Diego Padres
# ...            ...                    ...         ...                   ...
# 699171         137   San Francisco Giants         135      San Diego Padres
# 698962         137   San Francisco Giants         135      San Diego Padres
# 597538         137   San Francisco Giants         135      San Diego Padres
# 538681         137   San Francisco Giants         135      San Diego Padres
# 632998         137   San Francisco Giants         135      San Diego Padres
#
#        venue_id          venue_name prev_pitchname  \
# 97305      2680          Petco Park           None
# 98726      2681  Citizens Bank Park             FF
# 110770     2394       Comerica Park             FF
# 38695      2536         TD Ballpark             KC
# 37245        31            PNC Park             SI
# ...         ...                 ...            ...
# 699171     2395         Oracle Park             FS
# 698962     2395         Oracle Park             FF
# 597538     2395         Oracle Park             SL
# 538681     2395         Oracle Park             FF
# 632998     2395         Oracle Park             FF
#
#                        prev_gameid prev_ab
# 97305                         None     NaN
# 98726   2021/04/01/atlmlb-phimlb-1    27.0
# 110770  2021/04/01/clemlb-detmlb-1     7.0
# 38695   2021/04/09/anamlb-tormlb-1     1.0
# 37245   2021/04/12/sdnmlb-pitmlb-1    12.0
# ...                            ...     ...
# 699171  2021/10/02/sdnmlb-sfnmlb-1    46.0
# 698962  2021/10/02/sdnmlb-sfnmlb-1    51.0
# 597538  2021/10/03/sdnmlb-sfnmlb-1    49.0
# 538681  2021/10/03/sdnmlb-sfnmlb-1    68.0
# 632998  2021/10/03/sdnmlb-sfnmlb-1    69.0
#
# [1039 rows x 35 columns]

# %%
X
# Out:
#         relspeed  spinrate  horzbreak
# 97305  -0.928929  1.045989  -0.583428
# 97304  -1.269308  1.474508  -1.331511
# 97303   0.909652  0.854880   0.423633
# 97302  -2.083452  1.222106  -1.065205
# 97301  -0.373274  1.829189  -0.499210
# ...          ...       ...        ...
# 536047  0.415908  1.134936  -0.580658
# 536048  0.316262  1.081046  -0.676423
# 536049  1.357040  0.426368   1.377799
# 536050  1.291903  0.278251   1.175653
# 536706  0.251875  1.176511  -0.797592
#
# [706074 rows x 3 columns]

# %%
# Time to Cluster :) 
kmeans = KMeans(n_clusters=8, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(random_state=42)

# %%
# Cluster assignments for each point 
X['cluster'] = kmeans.labels_

# Cluster centroids 
centroids = kmeans.cluster_centers_

# %%
# %matplotlib notebook

# %%
# Ensure that interactive mode is on
# plt.ion()  # Turns on interactive mode

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Give each cluster a diff color 
scatter = ax.scatter(X['relspeed'], X['spinrate'], X['horzbreak'], c=X['cluster'], cmap='viridis', marker='o')

# plot centroids
ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2], s=300, c='red', marker='x', label='Centroids')

# labels
ax.set_xlabel('Release Speed')
ax.set_ylabel('Spin Rate')
ax.set_zlabel('Horizontal Break')
ax.set_title('KMeans Clustering of Pitches')

# legend for clusters
legend1 = ax.legend(*scatter.legend_elements(), title="Clusters")
ax.add_artist(legend1)

# legend for centroids
ax.legend(['Centroids'], loc='upper right')

# Show plot
plt.show()

# plt.pause(0.1)  # Small pause to keep the plot interactive

# %%
# Calculate the silhouette score
score = silhouette_score(X, kmeans.labels_)
print(f'Silhouette Score: {score}')
